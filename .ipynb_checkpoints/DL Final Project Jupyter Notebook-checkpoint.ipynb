# %% [markdown]
# # Classifying Food Images using Deep Learning
# **by: Chelsea Anne S. Ong**

# %% [markdown]
# **Libraries Used**

# %%
import os
import cv2
import argparse
import numpy as np
import pandas as pd

from collections import Counter

from keras.callbacks import Callback,EarlyStopping
from keras.backend import clear_session
from keras.models import Model, load_model
from keras.layers import Dense, Input, Flatten
from keras.applications import ResNet50, MobileNet, Xception, DenseNet121,InceptionV3,InceptionResNetV2,MobileNetV2

from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Executive Summary
#
# A certain image does not only necessarily represent a single attribute and most of the times it represents more than two. In other words, there can be multiple titles or labels that can be given for a single image. This problem is called multi-label classification which is used for content retrieval and scene understanding among few. For this study, a multi label classification algorithm is applied on food images using Keras (with Tensorflow backend). A simple CNN model is altered to give way to multi label classification. To make things easier, pre-trained CNN models are used particularly ResNet50, MobileNet, DenseNet121, and Xception. Afterwards, comparison of these results shall be done with Nanonets Multi Label Classification API. The results show a better F1 score at 75.06% for Nanonets and only about 70.46% for Xception model. Both of these models can be used for deployment as they both display intuitive and sound results.

# %% [markdown]
# ## Introduction
#
# When we see certain food images, are they easy to describe? Sometimes yes, sometimes no. Because of this, I want to explore if Deep Learning can help me with classifying food images. Using the sample food images data gathered from the blog "How To Easily Classify Food Using Deep Learning and Tensorflow", I shall run pre-trained CNN models to predict labels for a particular food image. Given a food item, I would like to know what are the possible labels for a certain food image. For instance, given an image of a beef, the model shall provide tag such as "meat", "protein". This model can be useful for content based retrieval for businesses especially for the food industry where automated dietary plan app can be made based on user requirements. The use of this model comes in by automatically retrieving relevant images for the specific food item.

# %% [markdown]
# ## About the Data
#
# ### Data Description
# The data consists of 2000 images which contain variety of food items. An image can have at most 10 possible labels. The list of labels are: [“Soups”, “Mains”, “Appetizer”, “Dessert” ,“Protein”, “Fats”, “Carbs”, “Healthy”, “Junk”, “Meat”]. To encode the labels in a format that can be utilized by the neural network, a 10 dimensional vector is created such that there is a “1” if a label is present in the image and “0” if a label is absent.

# %%
df = pd.read_csv('clean_anno_reduced.csv')
df.head()
# Out:
#              item  healthy  junk  dessert  appetizer  mains  soups  carbs  \
# 0       apple_pie        0     0        1          0      0      0      1
# 1  baby_back_ribs        0     0        0          0      1      0      0
# 2      beef_tacos        0     0        0          0      1      0      1
# 3      beet_salad        1     0        0          0      1      0      0
# 4   bread_pudding        0     0        1          0      0      0      1
#
#    protein  fats  meat
# 0        0     1     0
# 1        1     1     1
# 2        1     1     1
# 3        1     0     0
# 4        0     1     0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 11 columns):
# item         56 non-null object
# healthy      56 non-null int64
# junk         56 non-null int64
# dessert      56 non-null int64
# appetizer    56 non-null int64
# mains        56 non-null int64
# soups        56 non-null int64
# carbs        56 non-null int64
# protein      56 non-null int64
# fats         56 non-null int64
# meat         56 non-null int64
# dtypes: int64(10), object(1)
# memory usage: 4.9+ KB

# %%
df.sum()
# Out:
# item         apple_piebaby_back_ribsbeef_tacosbeet_saladbre...
# healthy                                                     12
# junk                                                        14
# dessert                                                     14
# appetizer                                                   15
# mains                                                       27
# soups                                                        4
# carbs                                                       42
# protein                                                     24
# fats                                                        34
# meat                                                        13
# dtype: object

# %% [markdown]
# ### Data Pre-Processing
# For this project, the dataset is divided into three: train set, validation set, and test set. The library used to pre-process the image is called cv2 or more known as OpenCV. OpenCV-Python is a library of Python bindings designed to solve computer vision problems.In order to read the file, the cv2.imread() method loads an image from the specified file. After loading the image, the cv2.COLOR_BGR2RGB method is used to convert color image of 256 pixels to RGB (red, green, blue). Every file is resized into 224 x 224 for analysis.
#
# For simplicity sake, the images in the first 30 folders would become the train set, the next 10 folders for the validation set, and the last 16 for folders as the test set.

# %%
def load_data(df):
    
    trainX, testX, valX = [], [], []
    trainY, testY, valY = [], [], []
    
    for i in range(len(df)):
        
        item = df.loc[i][0]
        current_label = np.array((df.loc[i])[1:])
        
        path = os.path.join('images', item)
        list_of_imgs = [os.path.join(path, file) for file in os.listdir(path)]
        train_set = list_of_imgs[:30]
        val_set = list_of_imgs[30:40]
        test_set = list_of_imgs[40:]
        
        for file in train_set:
            img = cv2.resize(cv2.cvtColor(cv2.imread(file, 1), cv2.COLOR_BGR2RGB), (224, 224))
            trainX.append(img)
            trainY.append(current_label)
        
        for file in val_set:
            img = cv2.resize(cv2.cvtColor(cv2.imread(file, 1), cv2.COLOR_BGR2RGB), (224, 224))
            valX.append(img)
            valY.append(current_label)
        
        for file in test_set:
            img = cv2.resize(cv2.cvtColor(cv2.imread(file, 1), cv2.COLOR_BGR2RGB), (224, 224))
            testX.append(img)
            testY.append(current_label)
            
    return (np.array(trainX), np.array(trainY), np.array(testX), 
            np.array(testY), np.array(valX), np.array(valY))

# %% [markdown]
# ### Data Normalization
#
# For fair prediction, the train set, validation set, and test set are all normalized. The method is shown below.

# %%
print('Loading Data...')
trainX, trainY, testX, testY, valX, valY = load_data(df)
print('Data Loaded.')

## Normalization

trainX = trainX.astype(np.float32)
testX = testX.astype(np.float32)
valX = valX.astype(np.float32)

trainY = trainY.astype(np.float32)
testY = testY.astype(np.float32)
valY = valY.astype(np.float32)

MEAN = np.mean(trainX, axis = (0,1,2))
STD = np.std(trainX, axis = (0,1,2))

for i in range(3):
    trainX[:, :, :, i] = (trainX[:, :, :, i] - MEAN[i]) / STD[i]
    testX[:, :, :, i] = (testX[:, :, :, i] - MEAN[i]) / STD[i]
    valX[:, :, :, i] = (valX[:, :, :, i] - MEAN[i]) / STD[i]
# Out:
# Loading Data...
# Data Loaded.

# %% [markdown]
# ### Dataset for Analysis
#
# The splitted dataset consists of these number of images.
#
# Set|Number of Images|
# --|--|
# Train|1676|
# Test|511|
# Val|544|

# %%
trainX.shape
# Out:
# (1676, 224, 224, 3)

# %%
testX.shape
# Out:
# (511, 224, 224, 3)

# %%
valX.shape
# Out:
# (544, 224, 224, 3)

# %% [markdown]
# ## Keras Model Implementation
#
# Using the Keras library, a model shall be created using some of the pre-train CNNs.
#
# ### Why Pre-trained CNNs?
# A pretrained network is a saved network that was previously trained on a large dataset, typically on a large-scale image-classification task. The reason for using a pre-trained network is because they can effectively act as a general model of the visual world. The most familiar and common training set is the ImageNet where classes are mostly animals and everyday subjects. It consists of 1.4 million labeled images and 1,000 different classes. Since foods are also considered as an everyday subject, we shall use this as a weight of the pretrained network.
#
# The final dense layer is set at **128 hidden nodes** and since the maximum number of labels is **10**, this is the number of nodes in the output layer. Notice that we also used a sigmoid layer for the output layer since they perform best on classification problems. While relu works best for hidden layers so we also use this.
#
# For compilation of the model, there are arguments to be watched out for such as optimizer, loss and accuracy.
#
# * The optimizer chosen is adam since the method is straightforward to implement, is computationally efficient, has little memory requirements, is invariant to diagonal rescaling of the gradients, and is well suited for problems that are large in terms of data and/or parameters. The method is also appropriate for non-stationary objectives and problems with very noisy and/or sparse gradients. The hyper-parameters have intuitive interpretations and typically require little tuning.
#
# * For binary classifications problems, Cross-entropy is the default loss function to use where the target values are in the set {0, 1}. Mathematically, it is the preferred loss function under the inference framework of maximum likelihood. It is the loss function to be evaluated first and only changed if you have a good reason. Cross-entropy will calculate a score that summarizes the average difference between the actual and predicted probability distributions for predicting class 1. The score is minimized and a perfect cross-entropy value is 0.
#
# * And for the metrics, accuracy is used since it is the most strict metric. It shall indicate the percentage of sample that have all their labels classified correctly.

# %%
def build_model(mode, model_name = None):

    clear_session()

    if mode == 'train':
        img = Input(shape = (224, 224, 3))

        if model_name == 'DenseNet121':

            model = DenseNet121(include_top=False, 
                                weights='imagenet', 
                                input_tensor=img, 
                                input_shape=None, 
                                pooling='avg')

        elif model_name == 'MobileNet':

            model = MobileNet(include_top=False, 
                              weights='imagenet', 
                              input_tensor=img, 
                              input_shape=None, 
                              pooling='avg')

        elif model_name == 'Xception':

            model = Xception(include_top=False, 
                             weights='imagenet', 
                             input_tensor=img, 
                             input_shape=None, 
                             pooling='avg')

        elif model_name == 'ResNet50':

            model = ResNet50(include_top=False, 
                             weights='imagenet', 
                             input_tensor=img, 
                             input_shape=None, 
                             pooling='avg')
        
        elif model_name == 'InceptionV3':

            model = InceptionV3(include_top=False, 
                             weights='imagenet', 
                             input_tensor=img, 
                             input_shape=None, 
                             pooling='avg')
            
        elif model_name == 'InceptionResNetV2':

            model = InceptionResNetV2(include_top=False, 
                             weights='imagenet', 
                             input_tensor=img, 
                             input_shape=None, 
                             pooling='avg')
            
        elif model_name == 'MobileNetV2':

            model = MobileNetV2(include_top=False, 
                             weights='imagenet', 
                             input_tensor=img, 
                             input_shape=None, 
                             pooling='avg')

        final_layer = model.layers[-1].output

        dense_layer_1 = Dense(128, activation = 'relu')(final_layer)
        output_layer = Dense(10, activation = 'sigmoid')(dense_layer_1)

        model = Model(inputs = img, outputs = output_layer)
        model.compile(optimizer = 'adam', loss = 'binary_crossentropy' , metrics = ['accuracy'])

    elif mode == 'inference':
        model = load_model(model_path)

    return model

# %% [markdown]
# #### Using F1 as a success metric
#
# Precision and Recall is both important in order to know how a model makes mistakes and what labels it misclassifies the most. Thus, F1 score shall be used.

# %%
def F1_score(y_true, y_pred):
    return f1_score(y_true, y_pred, average='samples')

# %% [markdown]
# ### Model Training Parameters
#
# To analyze the performance, we run the experiment with different models pre-trained on the ImageNet dataset. Overall, the following pre-trained models were used:
#
# 1. ResNet-50
# 2. DenseNet-121
# 3. Xception
# 4. MobileNet
#
# The number of epochs is set to 25 since increasing it further does not increase the validation accuracy. The batch size is set to default at 32.
#
# The code below shall provide predictions for each model specifically on the F1 score and sample prediction on the oreo image.

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
MEAN = np.array([51.072815, 51.072815, 51.072815])
STD = np.array([108.75629,  92.98068,  85.61884])

categories = [
'healthy', 'junk', 'dessert', 'appetizer', 'mains', 'soups', 'carbs', 'protein', 'fats', 'meat'
]

img = np.expand_dims(cv2.resize(cv2.cvtColor(cv2.imread('oreo.jpg',1),cv2.COLOR_BGR2RGB),(224,224)), axis = 0)


for i in range(3):
    img[:, :, :, i] = (img[:, :, :, i] - MEAN[i]) / STD[i]

# %% [markdown]
# ## Model Training Proper

# %% [markdown]
# ### ResNet50

# %%
model_1 = build_model('train',model_name = 'ResNet50')
history_1=model_1.fit(trainX, trainY, batch_size = 32, epochs = 25, validation_data = (valX, valY))
# Out:
# Train on 1676 samples, validate on 544 samples
# Epoch 1/25
# 1676/1676 [==============================] - 27s 16ms/step - loss: 0.5554 - acc: 0.7291 - val_loss: 4.8128 - val_acc: 0.6662
# Epoch 2/25
# 1676/1676 [==============================] - 15s 9ms/step - loss: 0.5107 - acc: 0.7462 - val_loss: 0.6113 - val_acc: 0.6627
# Epoch 3/25
# 1676/1676 [==============================] - 15s 9ms/step - loss: 0.4788 - acc: 0.7718 - val_loss: 0.6653 - val_acc: 0.6947
# Epoch 4/25
# 1676/1676 [==============================] - 15s 9ms/step - loss: 0.4653 - acc: 0.7773 - val_loss: 1.0296 - val_acc: 0.6419
# Epoch 5/25
# 1676/1676 [==============================] - 15s 9ms/step - loss: 0.4184 - acc: 0.8016 - val_loss: 0.7675 - val_acc: 0.6621
# Epoch 6/25
# 1676/1676 [==============================] - 15s 9ms/step - loss: 0.3726 - acc: 0.8304 - val_loss: 0.7994 - val_acc: 0.6840
# Epoch 7/25
# ...

# %%
model_1.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 64) 0           bn_conv1[0][0]
# ...

# %%
score_1 = F1_score(testY, model_1.predict(testX).round())
print('F1 Score =', score_1)

prediction_1 = np.round(model_1.predict(img)[0])
labels_1 = [categories[idx] for idx, current_prediction in enumerate(prediction_1) if current_prediction == 1]
print('Prediction:', labels_1)
# Out:
# F1 Score = 0.6514847948311744
# Prediction: ['dessert', 'carbs', 'fats']
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in samples with no predicted labels.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### MobileNet

# %%
model_2 = build_model('train', model_name = 'MobileNet')

## Training model.
history_2=model_2.fit(trainX, trainY, batch_size = 32, epochs = 25, validation_data = (valX, valY))
# Out:
# /opt/conda/lib/python3.6/site-packages/keras_applications/mobilenet.py:207: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '
# Train on 1676 samples, validate on 544 samples
# Epoch 1/25
# 1676/1676 [==============================] - 13s 8ms/step - loss: 0.5109 - acc: 0.7510 - val_loss: 0.8519 - val_acc: 0.7162
# Epoch 2/25
# 1676/1676 [==============================] - 9s 5ms/step - loss: 0.3389 - acc: 0.8478 - val_loss: 0.6403 - val_acc: 0.7482
# Epoch 3/25
# 1676/1676 [==============================] - 8s 5ms/step - loss: 0.2379 - acc: 0.8990 - val_loss: 0.7069 - val_acc: 0.7263
# Epoch 4/25
# 1676/1676 [==============================] - 9s 5ms/step - loss: 0.1791 - acc: 0.9271 - val_loss: 0.6064 - val_acc: 0.7597
# Epoch 5/25
# ...

# %%
model_2.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 225, 225, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# ...

# %%
score_2 = F1_score(testY, model_2.predict(testX).round())
print('F1 Score =', score_2)

prediction_2 = np.round(model_2.predict(img)[0])
labels_2 = [categories[idx] for idx, current_prediction in enumerate(prediction_2) if current_prediction == 1]
print('Prediction:', labels_2)
# Out:
# F1 Score = 0.6081096116321165
# Prediction: ['dessert', 'carbs', 'fats']

# %% [markdown]
# ### DenseNet121

# %%
model_3 = build_model('train', model_name = 'DenseNet121')

## Training model.
history_3=model_3.fit(trainX, trainY, batch_size = 32, epochs = 25, validation_data = (valX, valY))
# Out:
# Train on 1676 samples, validate on 544 samples
# Epoch 1/25
# 1676/1676 [==============================] - 43s 26ms/step - loss: 0.5443 - acc: 0.7301 - val_loss: 0.6349 - val_acc: 0.7072
# Epoch 2/25
# 1676/1676 [==============================] - 18s 11ms/step - loss: 0.4557 - acc: 0.7792 - val_loss: 0.9868 - val_acc: 0.6675
# Epoch 3/25
# 1676/1676 [==============================] - 18s 11ms/step - loss: 0.4144 - acc: 0.8057 - val_loss: 0.7820 - val_acc: 0.6928
# Epoch 4/25
# 1676/1676 [==============================] - 18s 11ms/step - loss: 0.3882 - acc: 0.8213 - val_loss: 0.8515 - val_acc: 0.6533
# Epoch 5/25
# 1676/1676 [==============================] - 18s 11ms/step - loss: 0.3407 - acc: 0.8467 - val_loss: 0.8674 - val_acc: 0.7070
# Epoch 6/25
# 1676/1676 [==============================] - 18s 11ms/step - loss: 0.3014 - acc: 0.8703 - val_loss: 0.5977 - val_acc: 0.7467
# Epoch 7/25
# ...

# %%
model_3.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 112, 112, 64) 9408        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 112, 112, 64) 0           conv1/bn[0][0]
# ...

# %%
score_3 = F1_score(testY, model_3.predict(testX).round())
print('F1 Score =', score_3)

prediction_3 = np.round(model_3.predict(img)[0])
labels_3 = [categories[idx] for idx, current_prediction in enumerate(prediction_3) if current_prediction == 1]
print('Prediction:', labels_3)
# Out:
# F1 Score = 0.6432125278504927
# Prediction: ['mains', 'carbs', 'protein', 'fats']

# %% [markdown]
# ### Xception

# %%
model_4 = build_model('train', model_name = 'Xception')

## Training model.
history_4=model_4.fit(trainX, trainY, batch_size = 32, epochs = 25, validation_data = (valX, valY))
# Out:
# Train on 1676 samples, validate on 544 samples
# Epoch 1/25
# 1676/1676 [==============================] - 33s 19ms/step - loss: 0.4861 - acc: 0.7671 - val_loss: 0.6169 - val_acc: 0.7765
# Epoch 2/25
# 1676/1676 [==============================] - 24s 14ms/step - loss: 0.3363 - acc: 0.8510 - val_loss: 0.5124 - val_acc: 0.8037
# Epoch 3/25
# 1676/1676 [==============================] - 24s 14ms/step - loss: 0.2579 - acc: 0.8909 - val_loss: 0.7199 - val_acc: 0.7494
# Epoch 4/25
# 1676/1676 [==============================] - 24s 14ms/step - loss: 0.2124 - acc: 0.9144 - val_loss: 0.5719 - val_acc: 0.7665
# Epoch 5/25
# 1676/1676 [==============================] - 24s 14ms/step - loss: 0.1722 - acc: 0.9308 - val_loss: 0.6993 - val_acc: 0.7945
# Epoch 6/25
# 1676/1676 [==============================] - 24s 14ms/step - loss: 0.1375 - acc: 0.9470 - val_loss: 0.6525 - val_acc: 0.7827
# Epoch 7/25
# ...

# %%
model_4.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 111, 111, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 111, 111, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 111, 111, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 109, 109, 64) 18432       block1_conv1_act[0][0]
# ...

# %%
score_4 = F1_score(testY, model_4.predict(testX).round())
print('F1 Score =', score_4)

prediction_4 = np.round(model_4.predict(img)[0])
labels_4 = [categories[idx] for idx, current_prediction in enumerate(prediction_4) if current_prediction == 1]
print('Prediction:', labels_4)
# Out:
# F1 Score = 0.7045790586886478
# Prediction: ['dessert', 'carbs', 'fats']

# %% [markdown]
# ## Keras Implementation Results
# ### Training and Validation Accuracy and Loss Plot
#
# As observed in the plots below at 25 epochs, the validation accuracy and loss plateaus and does not reach training values which are almost perfect. The gap only shows that the model is overfitting. But nevertheless, these are already fair enough results.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

acc_1 = history_1.history['acc']
val_acc_1 = history_1.history['val_acc']
loss_1 = history_1.history['loss']
val_loss_1 = history_1.history['val_loss']

acc_2 = history_2.history['acc']
val_acc_2 = history_2.history['val_acc']
loss_2 = history_2.history['loss']
val_loss_2 = history_2.history['val_loss']

acc_3 = history_3.history['acc']
val_acc_3 = history_3.history['val_acc']
loss_3 = history_3.history['loss']
val_loss_3 = history_3.history['val_loss']

acc_4 = history_4.history['acc']
val_acc_4 = history_4.history['val_acc']
loss_4 = history_4.history['loss']
val_loss_4 = history_4.history['val_loss']

epochs = range(1, len(acc_1) + 1)

# %%
fig,ax1=plt.subplots(4,1,figsize=(15,20))
plt.suptitle("Training and validation accuracy",fontsize=30)
ax1[0].plot(epochs, acc_1, 'bo', label='Training acc')
ax1[0].plot(epochs, val_acc_1, 'b', label='Validation acc')
ax1[0].set_title('ResNet50')
ax1[0].legend()

ax1[1].plot(epochs, acc_2, 'bo', label='Training acc')
ax1[1].plot(epochs, val_acc_2, 'b', label='Validation acc')
ax1[1].set_title('MobileNet')
ax1[1].legend()

ax1[2].plot(epochs, acc_3, 'bo', label='Training acc')
ax1[2].plot(epochs, val_acc_3, 'b', label='Validation acc')
ax1[2].set_title('DenseNet121')
ax1[2].legend()

ax1[3].plot(epochs, acc_4, 'bo', label='Training acc')
ax1[3].plot(epochs, val_acc_4, 'b', label='Validation acc')
ax1[3].set_title('Xception')
ax1[3].legend()

plt.show()

# %%
fig,ax1=plt.subplots(4,1,figsize=(15,20))
plt.suptitle("Training and validation loss",fontsize=30)
ax1[0].plot(epochs, loss_1, 'bo', label='Training loss')
ax1[0].plot(epochs, val_loss_1, 'b', label='Validation loss')
ax1[0].set_title('ResNet50')
ax1[0].legend()

ax1[1].plot(epochs, loss_2, 'bo', label='Training loss')
ax1[1].plot(epochs, val_loss_2, 'b', label='Validation loss')
ax1[1].set_title('MobileNet')
ax1[1].legend()

ax1[2].plot(epochs, loss_3, 'bo', label='Training loss')
ax1[2].plot(epochs, val_loss_3, 'b', label='Validation loss')
ax1[2].set_title('DenseNet121')
ax1[2].legend()

ax1[3].plot(epochs, loss_4, 'bo', label='Training loss')
ax1[3].plot(epochs, val_loss_4, 'b', label='Validation loss')
ax1[3].set_title('Xception')
ax1[3].legend()

plt.show()

# %% [markdown]
# ### Keras Summary Results

# %%
scores=[]
scores.append(score_1)
scores.append(score_2)
scores.append(score_3)
scores.append(score_4)

train_acc=[]
train_acc.append(acc_1[-1])
train_acc.append(acc_2[-1])
train_acc.append(acc_3[-1])
train_acc.append(acc_4[-1])

val_acc=[]
val_acc.append(max(val_acc_1))
val_acc.append(max(val_acc_2))
val_acc.append(max(val_acc_3))
val_acc.append(max(val_acc_4))

sample_pred=[]
sample_pred.append(labels_1)
sample_pred.append(labels_2)
sample_pred.append(labels_3)
sample_pred.append(labels_4)

models=['ResNet50', 'MobileNet', 'DenseNet121','Xception']

training=[16, 10, 18,24]

# %%
summary=pd.DataFrame(zip(models,scores,train_acc,val_acc,training, sample_pred),
             columns=['Model','F1 Score','train_acc','val_acc',
                      'Training time per epoch (s)','oreo_pred'])

# %%
summary=summary.set_index('Model')

# %%
summary_df=summary.T
summary_df
# Out:
# Model                                      ResNet50  \
# F1 Score                                   0.651485
# train_acc                                  0.992721
# val_acc                                    0.787316
# Training time per epoch (s)                      16
# oreo_pred                    [dessert, carbs, fats]
#
# Model                                            MobileNet  \
# F1 Score                                           0.60811
# train_acc                                         0.994451
# val_acc                                           0.789338
# Training time per epoch (s)                             10
# oreo_pred                    [mains, carbs, protein, fats]
#
# Model                                          DenseNet121  \
# F1 Score                                          0.643213
# train_acc                                         0.971718
# val_acc                                           0.811949
# ...

# %% [markdown]
# By comparing these four models, the results are not that far from each other. For the oreo image, it was able to predict it almost correctly. Different models have different architectures so it is important to at least be aware of how a certain architecture is made and where is it based on.

# %%
import seaborn as sns
sns.scatterplot(x=summary['F1 Score'],y=summary['Training time per epoch (s)'],hue=summary.index)

# %%
sns.scatterplot(x=summary['val_acc'],y=summary['Training time per epoch (s)'],hue=summary.index)

# %% [markdown]
# ### Keras Implementation Insights
#
# By comparing the four models, Xception consistenly gave the highest F1 score and validation accuracy, however, the training time of which is higher by about 30% compared to other pre-trained models. The use of each model depends on metric matters like time, accuracy. If shorter training time matters more, then MobileNet is the way to go. But for accuracy and F1 Score, Xception gives a better result.
#
# **Please take note that the results above are for this dataset only and does not necessarily work for other datasets.**
#
# Another thing I noticed as to why using Convolutional Neural Networks (CNN) can take so much time is because of the following:
# 1. Finding the optimal hyperparameters for best performance is done by trial and error.
# 2. If data augmentation is made, the training time increases as a tradeoff for better performance.
# 3. CNNs are computationally expensive, in hardware and time. Better GPU means faster computations.
# 4. Deploying this model to production needs effort, time and skill.

# %% [markdown]
# ## Introducing Nanonets
#
# Nanonets has an easy to use API not only for Mulltilabel Classification but also for Object Detection, Optical Character Recognition and anything that concerns images. What separates Nanonets from the typical Keras models is that it also does all the things in order to improve the model. These includes, data augmentation, transfer learning, hyperparameter search on their GPU clusters. The overall process from training to prediction only takes 30 minutes up to an hour. Aside from that, it also has an API where those who aren't that proficient in programming can also do the similar things I have done.
#
# In order to set up all of this, it only takes 5 steps and listed as follows:
# 1. Creation of Nanonets model
# 2. Uploading of the images on the API
# 3. Model Training
# 4. Check if training is done
# 5. Predict using Nanonets

# %% [markdown]
# ### Create Model

# %%
import requests 
import json
import os

BASE_URL = 'http://app.nanonets.com/api/v2/MultiLabelClassification/'
AUTH_KEY = os.environ.get('NANONETS_API_KEY')


categories = [
'healthy', 'junk', 'dessert', 'appetizer', 'mains', 'soups', 'carbs', 'protein', 'fats', 'meat'
]


ext = ['.jpg']


def create_new_model(categories):
    try:
        url = BASE_URL + "Model/"
        data = json.dumps({'categories' : categories})

        response = requests.request("POST", url, auth=requests.auth.HTTPBasicAuth('Kvjm_6mqQxwXzTrMo3TdSxvaZw-qNrbo', ''), data=data)
        result = json.loads(response.text)
        return result['model_id']
    except:
        raise ValueError("Error in creating model")

model_id = create_new_model(categories)

# %%
model_id
# Out:
# '7b2b981e-86e9-4e0c-ad9e-bc8b22fb48a5'

# %% [markdown]
# ### Create dictionary and upload images on web
#
# Nanonets requires the dataset to be provided in a particular format which is executed by the code below.

# %%
import requests 
import json
import os
import random

BASE_URL = 'http://app.nanonets.com/api/v2/MultiLabelClassification/'
AUTH_KEY = os.environ.get('NANONETS_API_KEY')
MODEL_ID = os.environ.get('NANONETS_MODEL_ID')

image_folder_path = "./multilabel_data/ImageSets/"
annotations_folder = "./multilabel_data/Annotations/"

def create_image_dictionary():
    image_label_dictionary = {}
    for image in os.listdir(image_folder_path):
        annotatios_file_name  = os.path.join(annotations_folder, "%s.txt"%(image.rsplit('.', 1)[0]))
        if not os.path.isfile(annotatios_file_name):
            continue
        all_labels = [x for x in open(annotatios_file_name, 'r').read().split('\n') if x]
        image_label_dictionary[os.path.join(image_folder_path, image)] = all_labels
    return image_label_dictionary

def upload_images(model_id):
    url = BASE_URL + 'Model/%s/UploadFiles/'%(model_id)
    print ("Uploading Images......")
    image_label_dictionary = create_image_dictionary()
    all_images = list(image_label_dictionary.keys())
    random.shuffle(all_images)
    n = len(all_images)
    image_uploaded = 0
    while len(all_images) > 0:
        batch_images, all_images = all_images[:50], all_images[50:]
        multiple_files = []
        multiple_data = []
        for image in batch_images:
            labels = image_label_dictionary[image]
            image_dir, image_name = os.path.split(image)
            image_data = {'filename': image_name, "categories": labels}
            multiple_data.append(image_data)
            multiple_files.append(('files', (image_name, open(image, 'rb'), 'image/jpeg')))
        multiple_files.append(('data', ('', json.dumps(multiple_data))))
        response = requests.post(url, auth= requests.auth.HTTPBasicAuth('Kvjm_6mqQxwXzTrMo3TdSxvaZw-qNrbo', ''), files=multiple_files)
        image_uploaded += len(batch_images)
        if len(all_images) > 0:
            print ("%d of %d images has been uploaded, uploading next batch...."%(image_uploaded, n))
        else:
            print ("%d of %d images has been uploaded, Done uploading"%(image_uploaded, n))
    return 


upload_images('7b2b981e-86e9-4e0c-ad9e-bc8b22fb48a5')
# Out:
# Uploading Images......
# 50 of 1671 images has been uploaded, uploading next batch....
# 100 of 1671 images has been uploaded, uploading next batch....
# 150 of 1671 images has been uploaded, uploading next batch....
# 200 of 1671 images has been uploaded, uploading next batch....
# 250 of 1671 images has been uploaded, uploading next batch....
# 300 of 1671 images has been uploaded, uploading next batch....
# 350 of 1671 images has been uploaded, uploading next batch....
# 400 of 1671 images has been uploaded, uploading next batch....
# 450 of 1671 images has been uploaded, uploading next batch....
# 500 of 1671 images has been uploaded, uploading next batch....
# 550 of 1671 images has been uploaded, uploading next batch....
# 600 of 1671 images has been uploaded, uploading next batch....
# 650 of 1671 images has been uploaded, uploading next batch....
# 700 of 1671 images has been uploaded, uploading next batch....
# 750 of 1671 images has been uploaded, uploading next batch....
# ...

# %% [markdown]
# ### Training of model
# Once the dataset is uploaded, training shall commence by executing the code below.

# %%
import requests 
import json
import os

BASE_URL = 'http://app.nanonets.com/api/v2/MultiLabelClassification/'
AUTH_KEY = os.environ.get('NANONETS_API_KEY')
MODEL_ID = os.environ.get('NANONETS_MODEL_ID')

def train(model_id):
    url = BASE_URL + 'Model/%s/Train/'%(model_id)
    response = requests.request('POST', url, auth=requests.auth.HTTPBasicAuth('Kvjm_6mqQxwXzTrMo3TdSxvaZw-qNrbo', ''))
    
    result = json.loads(response.text)
    print(result)

# if __name__=="__main__":
train('7b2b981e-86e9-4e0c-ad9e-bc8b22fb48a5')
# Out:
# {'model_id': '7b2b981e-86e9-4e0c-ad9e-bc8b22fb48a5', 'model_type': 'multilabelclassification', 'state': 3, 'status': 'In queue for training', 'accuracy': 0, 'categories': [{'name': 'carbs', 'count': 0}, {'name': 'junk', 'count': 0}, {'name': 'mains', 'count': 0}, {'name': 'soups', 'count': 0}, {'name': 'appetizer', 'count': 0}, {'name': 'dessert', 'count': 0}, {'name': 'fats', 'count': 0}, {'name': 'healthy', 'count': 0}, {'name': 'meat', 'count': 0}, {'name': 'protein', 'count': 0}], 'email': '', 'is_public': False}
#
#
# NEXT RUN: python ./code/model_state.py

# %% [markdown]
# ### Check if training is done
# The code below will keep me updated about the current state of the model.

# %%
import requests 
import json
import os

BASE_URL = 'http://app.nanonets.com/api/v2/MultiLabelClassification/'
AUTH_KEY = os.environ.get('NANONETS_API_KEY')
MODEL_ID = os.environ.get('NANONETS_MODEL_ID')

def get_model(model_id):
    url = BASE_URL + "Model/%s"%(model_id)
    response = requests.request('GET', url, auth=requests.auth.HTTPBasicAuth('Kvjm_6mqQxwXzTrMo3TdSxvaZw-qNrbo',''))
    res =  json.loads(response.text)
    state, status  = res['state'], res['status']
    if state != 5:
        print("The model isn't ready yet, it's status is:", status)
        print("We will send you an email when the model is ready. If your imapatient, run this script again in 10 minutes to check.")
        print("\n\nmore details at:")
        print("https://app.nanonets.com/multilabelclassification/#/classify/"+model_id)
    else:
        print("NEXT RUN: python ./code/prediction.py ./multilabel_data/ImageSets/1067.jpg")


# if __name__=="__main__":
get_model('7b2b981e-86e9-4e0c-ad9e-bc8b22fb48a5')
# Out:
# NEXT RUN: python ./code/prediction.py ./multilabel_data/ImageSets/1067.jpg

# %% [markdown]
# ### Nanonets Prediction
# After the training of the model is finished, prediction can be made on any image that will be uploaded.

# %%
import requests 
import json
import os
import sys


BASE_URL = 'http://app.nanonets.com/api/v2/MultiLabelClassification/'
AUTH_KEY = os.environ.get('NANONETS_API_KEY')
MODEL_ID = os.environ.get('NANONETS_MODEL_ID')


def predict(image_file_path, model_id):
    url = BASE_URL + 'Model/%s/LabelFiles/'%(model_id)
    data = {'files': open(image_file_path, 'rb')}

    response = requests.post(url, auth= requests.auth.HTTPBasicAuth('Kvjm_6mqQxwXzTrMo3TdSxvaZw-qNrbo', ''), files=data)
    return (json.loads(response.text))
    print(json.loads(response.text))

# %% [markdown]
# ### Sample Predictions for Nanonets
# The sample predictions for Nanonets models are shown below. The results are shown by probability that a certain label describes a certain image.

# %% [markdown]
# #### Oreo image
# <img src='oreo.jpg' height="300" width="300">

# %%
dessert=predict('oreo.jpg', '7b2b981e-86e9-4e0c-ad9e-bc8b22fb48a5')
pd.DataFrame(dessert['result'][0]['prediction'])
# Out:
#        label  probability
# 0      carbs     0.742765
# 1       fats     0.718950
# 2    dessert     0.465264
# 3      mains     0.267923
# 4    protein     0.220833
# 5       meat     0.079017
# 6    healthy     0.029848
# 7       junk     0.006696
# 8  appetizer     0.004580
# 9      soups     0.002509

# %% [markdown]
# #### Fries image
# <img src='download.jpg' height="300" width="500">

# %%
fries=predict('download.jpeg', '7b2b981e-86e9-4e0c-ad9e-bc8b22fb48a5')
pd.DataFrame(fries['result'][0]['prediction'])
# Out:
#        label  probability
# 0      carbs     0.976004
# 1       junk     0.833237
# 2      mains     0.666144
# 3       fats     0.656888
# 4  appetizer     0.224680
# 5    protein     0.076790
# 6       meat     0.075137
# 7    healthy     0.001538
# 8      soups     0.001518
# 9    dessert     0.000605

# %% [markdown]
# #### steak image
# <img src='steak_sarap.jpg' height="300" width="500">

# %%
steak=predict('steak_sarap.jpg', '7b2b981e-86e9-4e0c-ad9e-bc8b22fb48a5')
pd.DataFrame(steak['result'][0]['prediction'])
# Out:
#        label  probability
# 0      mains     0.949295
# 1       meat     0.941687
# 2    protein     0.913218
# 3       fats     0.858665
# 4    healthy     0.087786
# 5      carbs     0.065086
# 6       junk     0.019836
# 7  appetizer     0.018433
# 8      soups     0.002715
# 9    dessert     0.002449

# %% [markdown]
# #### Pizza image
# <img src='supreme.png' height="300" width="500">

# %%
pizza=predict('supreme.png', '7b2b981e-86e9-4e0c-ad9e-bc8b22fb48a5')
pd.DataFrame(pizza['result'][0]['prediction'])
# Out:
#        label  probability
# 0      carbs     0.970634
# 1       fats     0.909548
# 2       meat     0.864349
# 3       junk     0.546142
# 4      mains     0.452339
# 5    protein     0.133071
# 6    dessert     0.069686
# 7  appetizer     0.037119
# 8    healthy     0.008761
# 9      soups     0.004430

# %% [markdown]
# #### Sinigang image
# <img src='sinigang.jpg' height="300" width="500">

# %%
sinigang=predict('sinigang.jpg', '7b2b981e-86e9-4e0c-ad9e-bc8b22fb48a5')
pd.DataFrame(sinigang['result'][0]['prediction'])
# Out:
#        label  probability
# 0      soups     0.948941
# 1    healthy     0.859049
# 2    protein     0.626899
# 3      mains     0.423656
# 4  appetizer     0.345357
# 5      carbs     0.250348
# 6       junk     0.057225
# 7       meat     0.050379
# 8       fats     0.024237
# 9    dessert     0.006039

# %% [markdown]
# ## Conclusion, Recommendations, Insights
#
# ### Conclusion
#
# Nanonets has clearly the faster running time than the Keras models, it can finish all processes within 30 minutes. Also, Nanonets clearly has a higher score than the Keras models. It is also important to take note that MobileNet also runs relatively fast and yields good results. Due to its more efficient architecture, it somehows lessens overfitting compared to the other Keras models. The other models have relatively lower scores which can be attributed to more complex architecture and also the size of the dataset is very small, and also noisy annotations.
#
# By visual observation, both Keras and Nanonets have made intuitive predictions of the model labels.
#
# ### Recommendations
#
# 1. To further increase the accuracy and the F1 score, use a larger dataset.
# 2. Perform data augmentation of Keras models and see if performance gets better.
# 3. Use other pre-trained CNN architectures and see how results would change.
#
# ### Insights
# 1. Train, fit and predict per model shall happen simultaneously. Predictions will not run if training each model is done first.
# 2. Annotations are subjective, therefore, this might also contribute to error.
# 3. Deep Learning models in general requires extensive hyperparameter tuning and the only way to do this is only by trial and error. The more technical expertise, the more efficient the process of prediction will be.
# 4. I also learned that there are a lot of Deep Learning model APIs online by which non coders can also use and achieve similar results. However, with knowledge on deep learning, there can be so much that can be done like nation building, invent a model after my name and so on.
# 5. Lastly, take note that the results I have generated are for this dataset only and does not necessarily work for other datasets.

# %% [markdown]
# ## Acknowledgements
#
# I would like to acknowledge the MSDS faculty for imparting with us their Data Science knowledge particularly Deep Learning. Special mention to Professor Christopher Monterola, Professor Erika Legara for educating us with the knowledge that I need to fully absorb the technicalities of the course as well as convey the results in such a way that it can really provide business value.
#
# I would also like to acknowledge the MSDS 2020 community for an inspiration throughout this journey. Being surrounded with the best of the best propels us forward towards further advancing ourselves.
#
# Also, I would like to acknowledge the blog "How To Easily Classify Food Using Deep Learning and Tensorflow" by Bharath Raj which has helped me further understand Deep Learning concepts particularly CNNs.
#
# For reference, refer to this link https://nanonets.com/blog/multi-label-classification-using-deep-learning/
